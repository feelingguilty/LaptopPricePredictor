# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("laptop_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(y=df['Company'],x=df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Company'>

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)
df['Touchsreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS  Touchsreen
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832    1           0
# ...

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['y_res'] = new[1]

# %%
df['x_res'] = new[0]

# %%
df['x_res'] = df['x_res'].str[-4:]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  IPS  Touchsreen  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832    1           0
# ...

# %%
df['x_res'] = df['x_res'].astype(int)
df['y_res'] = df['y_res'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  IPS               1303 non-null   int64
#  12  Touchsreen        1303 non-null   int64
#  13  y_res             1303 non-null   int32
#  14  x_res             1303 non-null   int32
# dtypes: float64(2), int32(2), int64(2), object(9)
# ...

# %%
df['ppi'] = (((df['x_res']**2) + (df['y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.drop(['x_res','y_res'],axis=1,inplace=True)

# %%
df.sample()
# Out:
#      Company  TypeName  Inches   ScreenResolution  \
# 593  Samsung  Notebook    15.6  Full HD 1920x1080
#
#                              Cpu   Ram                Memory  \
# 593  Intel Core i7 7700HQ 2.8GHz  16GB  128GB SSD +  1TB HDD
#
#                          Gpu       OpSys Weight     Price  IPS  Touchsreen  \
# 593  Nvidia GeForce GTX 1050  Windows 10  2.5kg  90522.72    0           0
#
#             ppi
# 593  141.211998

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
df.sample()
# Out:
#       Company   TypeName  Inches   ScreenResolution  \
# 1118  Toshiba  Ultrabook    13.3  Full HD 1920x1080
#
#                              Cpu   Ram     Memory                    Gpu  \
# 1118  Intel Core i7 7500U 2.7GHz  16GB  512GB SSD  Intel HD Graphics 620
#
#            OpSys  Weight      Price  IPS  Touchsreen         ppi  \
# 1118  Windows 10  1.05kg  118601.28    0           0  165.632118
#
#            Cpu Name
# 1118  Intel Core i7

# %%
df['Cpu Name'].value_counts()
# Out:
# Cpu Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x=df['Cpu Brand'],y=df['Price'])
# Out:
# <Axes: xlabel='Cpu Brand', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company  TypeName  Inches ScreenResolution                         Cpu  \
# 614    Dell  Notebook    15.6         1366x768  Intel Core i5 7300U 2.6GHz
#
#      Ram     Memory                    Gpu  OpSys  Weight     Price  IPS  \
# 614  4GB  500GB HDD  Intel HD Graphics 620  Linux  1.93kg  46300.32    0
#
#      Touchsreen        ppi       Cpu Name      Cpu Brand
# 614           0  100.45467  Intel Core i5  Intel Core i5

# %%
df.drop(['Cpu','Cpu Name'],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#       Company     TypeName  Inches                           ScreenResolution  \
# 159   Toshiba     Notebook    15.6                                   1366x768
# 610    Lenovo     Notebook    15.6            IPS Panel 4K Ultra HD 3840x2160
# 905        LG    Ultrabook    15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 950        HP  Workstation    15.6                IPS Panel Full HD 1920x1080
# 1212      MSI       Gaming    17.3                IPS Panel Full HD 1920x1080
#
#        Ram                Memory                      Gpu       OpSys  Weight  \
# 159    4GB             500GB HDD    Intel HD Graphics 520  Windows 10   2.1kg
# 610   32GB               1TB SSD     Nvidia Quadro M2200M  Windows 10   2.5kg
# 905   16GB             512GB SSD    Intel HD Graphics 620  Windows 10  1.08kg
# 950    8GB               8GB SSD     Nvidia Quadro M1000M  Windows 10   2.0kg
# 1212  16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10  2.43kg
#
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '024')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')
df['first'] = df['first'].apply(lambda x:''.join(x.split()[0:1]))
df['second'] = df['second'].apply(lambda x:''.join(x.split()[0:1]))
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution   Ram  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600   8GB
# 1   Apple  Ultrabook    13.3                            1440x900   8GB
# 2      HP   Notebook    15.6                   Full HD 1920x1080   8GB
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800  16GB
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600   8GB
#
#               Memory                           Gpu  OpSys  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256 SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512 SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256 SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  IPS  Touchsreen         ppi      Cpu Brand  HDD  SSD  Hybrid  \
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution  Ram             Gpu  \
# 726    Dell  Notebook    15.6  Full HD 1920x1080  8GB  AMD Radeon 530
#
#           OpSys Weight     Price  IPS  Touchsreen         ppi      Cpu Brand  \
# 726  Windows 10  2.2kg  38308.32    0           0  141.211998  Intel Core i5
#
#       HDD  SSD  Hybrid  Flash_Storage
# 726  1024  128       0              0

# %%
df.sample()
# Out:
#     Company TypeName  Inches       ScreenResolution   Ram  \
# 808    Dell   Gaming    15.6  4K Ultra HD 3840x2160  16GB
#
#                             Gpu       OpSys  Weight     Price  IPS  \
# 808  Nvidia GeForce GTX 1050 Ti  Windows 10  2.62kg  89457.12    0
#
#      Touchsreen         ppi      Cpu Brand  HDD  SSD  Hybrid  Flash_Storage
# 808           0  282.423996  Intel Core i7    0  512       0              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Ram               1303 non-null   object
#  5   Gpu               1303 non-null   object
#  6   OpSys             1303 non-null   object
#  7   Weight            1303 non-null   object
#  8   Price             1303 non-null   float64
#  9   IPS               1303 non-null   int64
#  10  Touchsreen        1303 non-null   int64
#  11  ppi               1303 non-null   float64
#  12  Cpu Brand         1303 non-null   object
#  13  HDD               1303 non-null   int64
#  14  SSD               1303 non-null   int64
#  15  Hybrid            1303 non-null   int64
# ...

# %%
df.drop(['Hybrid','Flash_Storage'],axis=1,inplace =True)

# %%
df.sample()
# Out:
#      Company     TypeName  Inches   ScreenResolution  Ram                 Gpu  \
# 1086      HP  Workstation    15.6  Full HD 1920x1080  8GB  AMD FirePro W4190M
#
#           OpSys Weight    Price  IPS  Touchsreen         ppi      Cpu Brand  \
# 1086  Windows 7  1.9kg  79653.6    0           0  141.211998  Intel Core i7
#
#       HDD  SSD
# 1086    0  256

# %%
df.drop(['ScreenResolution'],axis=1,inplace=True)

# %%
df.sample()
# Out:
#    Company  TypeName  Inches  Ram             Gpu       OpSys Weight    Price  \
# 27    Dell  Notebook    15.6  8GB  AMD Radeon 530  Windows 10  2.2kg  42624.0
#
#     IPS  Touchsreen         ppi      Cpu Brand  HDD  SSD
# 27    0           0  141.211998  Intel Core i5    0  256

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.sample()
# Out:
#     Company  TypeName  Inches Ram                    Gpu  OpSys Weight  \
# 261  Lenovo  Notebook    15.6   4  Intel HD Graphics 520  No OS    2.2
#
#         Price  IPS  Touchsreen         ppi      Cpu Brand  HDD  SSD
# 261  23656.32    0           0  141.211998  Intel Core i3    0  256

# %%
df['Gpu']
# Out:
# 0       Intel Iris Plus Graphics 640
# 1             Intel HD Graphics 6000
# 2              Intel HD Graphics 620
# 3                 AMD Radeon Pro 455
# 4       Intel Iris Plus Graphics 650
#                     ...
# 1298           Intel HD Graphics 520
# 1299           Intel HD Graphics 520
# 1300               Intel HD Graphics
# 1301              AMD Radeon R5 M330
# 1302               Intel HD Graphics
# Name: Gpu, Length: 1303, dtype: object

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x:''.join(x.split()[0:1]))

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu Brand'] != 'ARM']

# %%
df.sample()
# Out:
#    Company TypeName  Inches Ram                      Gpu       OpSys Weight  \
# 93    Dell   Gaming    15.6   8  Nvidia GeForce GTX 1060  Windows 10   2.65
#
#       Price  IPS  Touchsreen         ppi      Cpu Brand  HDD  SSD Gpu Brand
# 93  63669.6    0           0  141.211998  Intel Core i5    0  256    Nvidia

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.sample()
# Out:
#     Company   TypeName  Inches Ram       OpSys Weight      Price  IPS  \
# 909      LG  Ultrabook    14.0   8  Windows 10   0.98  101178.72    1
#
#      Touchsreen         ppi      Cpu Brand  HDD  SSD Gpu Brand
# 909           1  157.350512  Intel Core i7    0  512     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def OperatingSys(text):
    if text == 'Windows 10' or text == 'Windows 7' or text == 'Windows 10 S':
        return 'Windows'
    elif text == ' Mac OS X' or text == 'macOS':
        return 'MAC'
    else:
        return 'No OS/Linux/Android'

# %%
df['OS'] = df['OpSys'].apply(OperatingSys)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches Ram       OpSys Weight    Price  IPS  \
# 765    Acer  Notebook    13.3   4  Windows 10    1.6  34898.4    0
#
#      Touchsreen        ppi      Cpu Brand  HDD  SSD Gpu Brand       OS
# 765           0  117.82653  Intel Core i5    0  128     Intel  Windows

# %%
df.drop(['OpSys'],axis=1,inplace=True)

# %%
df.drop(['Inches'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram Weight        Price  IPS  Touchsreen         ppi  \
# 0   Apple  Ultrabook   8   1.37   71378.6832    1           0  226.983005
# 1   Apple  Ultrabook   8   1.34   47895.5232    0           0  127.677940
# 2      HP   Notebook   8   1.86   30636.0000    0           0  141.211998
# 3   Apple  Ultrabook  16   1.83  135195.3360    1           0  220.534624
# 4   Apple  Ultrabook   8   1.37   96095.8080    1           0  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand                   OS
# 0  Intel Core i5    0  128     Intel                  MAC
# 1  Intel Core i5    0    0     Intel                  MAC
# 2  Intel Core i5    0  256     Intel  No OS/Linux/Android
# 3  Intel Core i7    0  512       AMD                  MAC
# 4  Intel Core i5    0  256     Intel                  MAC

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\bhush\AppData\Local\Temp\ipykernel_5816\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\bhush\AppData\Local\Temp\ipykernel_5816\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# # ALGORITHMS

# %%
X = df.drop(['Price'],axis=1)
y = np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
y_test.head()
# Out:
# 248     10.490274
# 555      9.387207
# 1251     9.964522
# 547     10.111883
# 885     11.470547
# Name: Price, dtype: float64

# %%
X_test.head()
# Out:
#      Company            TypeName Ram Weight  IPS  Touchsreen         ppi  \
# 248       HP            Notebook   4   1.49    1           0  165.632118
# 555     Asus            Notebook   4      2    0           0  100.454670
# 1251      HP            Notebook   4   1.86    0           0  100.454670
# 547   Lenovo            Notebook   4   2.15    0           0  141.211998
# 885       HP  2 in 1 Convertible   4   1.28    0           1  165.632118
#
#                   Cpu Brand   HDD  SSD Gpu Brand                   OS
# 248           Intel Core i5   500    0     Intel              Windows
# 555   Other Intel Processor   500    0     Intel  No OS/Linux/Android
# 1251          AMD Processor   500    0       AMD              Windows
# 547           Intel Core i5  1024    0     Intel  No OS/Linux/Android
# 885           Intel Core i5     0  256     Intel              Windows

# %%
X_test.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'IPS', 'Touchsreen', 'ppi',
#        'Cpu Brand', 'HDD', 'SSD', 'Gpu Brand', 'OS'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import Ridge

# %% [markdown]
# Linear Regression

# %%
tnf1 = ColumnTransformer(transformers=[('tnf',OneHotEncodr(sparse=False,drop='first'),[0,1,7,10,11])],remainder='passthrough')
tnf2 = LinearRegression()

pipe = Pipeline([
    ('tnf1',tnf1),
    ('tnf2',tnf2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# MAE: 0.20951449203335365
# C:\Users\bhush\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Ridge Regression

# %%
tnf1 = ColumnTransformer(transformers=[('tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],remainder='passthrough')
tnf2 = Ridge(alpha=10)

pipe = Pipeline([
    ('tnf1',tnf1),
    ('tnf2',tnf2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# MAE: 0.2094751405534711
# C:\Users\bhush\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName Ram Weight        Price  IPS  Touchsreen  \
# 0      Apple           Ultrabook   8   1.37   71378.6832    1           0
# 1      Apple           Ultrabook   8   1.34   47895.5232    0           0
# 2         HP            Notebook   8   1.86   30636.0000    0           0
# 3      Apple           Ultrabook  16   1.83  135195.3360    1           0
# 4      Apple           Ultrabook   8   1.37   96095.8080    1           0
# ...      ...                 ...  ..    ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible   4    1.8   33992.6400    1           1
# 1299  Lenovo  2 in 1 Convertible  16    1.3   79866.7200    1           1
# 1300  Lenovo            Notebook   2    1.5   12201.1200    0           0
# 1301      HP            Notebook   6   2.19   40705.9200    0           0
# 1302    Asus            Notebook   4    2.2   19660.3200    0           0
#
#              ppi              Cpu Brand   HDD  SSD Gpu Brand  \
# ...

# %%
pipe
# Out:
# Pipeline(steps=[('tnf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 7, 10, 11])])),
#                 ('tnf2', Ridge(alpha=10))])
